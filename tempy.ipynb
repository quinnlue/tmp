# %%
from datasets import load_dataset

ds = load_dataset("benjamin-paine/imagenet-1k-128x128")

# %%
ds['train']['label']
# Out:
# Column([0, 0, 0, 0, 0, ...])

# %%
from label_mappings import label2idx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from label_mappings import label2idx
#
# ModuleNotFoundError: No module named 'label_mappings'
